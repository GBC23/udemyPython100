# %%
def my_function():
  print('Hello there')
  print('Today is a good day. Isn\'t it Aeh?')

my_function()
# Out:
# Hello there
# Today is a good day. Isn't it Aeh?

# %%
def my_function(name):
  print(f'Helle {name}!')
  print(f'How do you do {name}?')

my_function('Yeongik')
my_function('Dave')
# Out:
# Helle Yeongik!
# How do you do Yeongik?
# Helle Dave!
# How do you do Dave?

# %%
# from os import name
def greet_with(name, location):
  print(f'Hello {name}')
  print('What is it like in {location}?')
